# %%
from web_cam_init import init_web_cam

init_web_cam("")
# Out:
# 0: 480x640 (no detections), 254.2ms
# Speed: 10.1ms preprocess, 254.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 191.4ms
# Speed: 4.4ms preprocess, 191.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 143.0ms
# Speed: 3.5ms preprocess, 143.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 196.6ms
# Speed: 3.9ms preprocess, 196.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 114.1ms
# Speed: 4.0ms preprocess, 114.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 95.6ms
# Speed: 2.3ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 102.2ms
# Speed: 2.2ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ...
