# %%
from web_cam_init import init_web_cam

init_web_cam("")
# Out:
# 0: 480x640 (no detections), 208.8ms
# Speed: 9.7ms preprocess, 208.8ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 183.9ms
# Speed: 2.5ms preprocess, 183.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 175.2ms
# Speed: 5.9ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 158.6ms
# Speed: 2.6ms preprocess, 158.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 185.0ms
# Speed: 5.0ms preprocess, 185.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 140.1ms
# Speed: 3.5ms preprocess, 140.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 128.5ms
# Speed: 0.0ms preprocess, 128.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 Can, 138.9ms
# ...
